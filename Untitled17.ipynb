# %% [markdown]
# <a href="https://colab.research.google.com/github/Arya-man12/MiscProjects/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b mixtral https://github.com/arcee-ai/mergekit.git
# !cd mergekit && pip install -e .
# !pip install -U transformers
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 2015, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 2015 (delta 80), reused 109 (delta 75), pack-reused 1886
# Receiving objects: 100% (2015/2015), 617.18 KiB | 17.14 MiB/s, done.
# Resolving deltas: 100% (1376/1376), done.
# Obtaining file:///content/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 28.3 MB/s eta 0:00:00
# ...

# %%
# !mergekit-moe config.yaml merge --copy-tokenizer --allow-crimes --out-shard-size 1B --lazy-unpickle
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# model-00003-of-00003.safetensors:  48% 2.18G/4.54G [00:50<01:36, 24.3MB/s]
#
# model-00001-of-00003.safetensors:  47% 2.31G/4.94G [00:51<00:34, 77.0MB/s]
#
#
# model-00003-of-00003.safetensors:  48% 2.19G/4.54G [00:50<01:22, 28.5MB/s]
#
#
#
# model-00002-of-00003.safetensors:  45% 2.24G/5.00G [00:50<00:36, 76.3MB/s]
#
#
# model-00003-of-00003.safetensors:  49% 2.21G/4.54G [00:50<00:55, 41.6MB/s]
#
#
#
# model-00002-of-00003.safetensors:  45% 2.26G/5.00G [00:50<00:31, 87.9MB/s]
#
# model-00001-of-00003.safetensors:  47% 2.33G/4.94G [00:51<00:38, 67.5MB/s]
#
#
# model-00003-of-00003.safetensors:  49% 2.23G/4.54G [00:51<00:42, 54.4MB/s]
#
#
#
# model-00002-of-00003.safetensors:  46% 2.29G/5.00G [00:51<00:28, 95.9MB/s]
#
# model-00001-of-00003.safetensors:  47% 2.34G/4.94G [00:51<00:36, 71.2MB/s]
#
#
# model-00003-of-00003.safetensors:  49% 2.24G/4.54G [00:51<00:38, 60.1MB/s]
#
# ...

# %%
# @title ## Upload model to Hugging Face { display-mode: "form" }
# @markdown Enter your HF username and the name of Colab secret that stores your [Hugging Face access token](https://huggingface.co/settings/tokens).
username = 'akthegr8' # @param {type:"string"}
token = 'Secret' # @param {type:"string"}
license = "apache-2.0" # @param ["apache-2.0", "cc-by-nc-4.0", "mit", "openrail"] {allow-input: true}

# !pip install -qU huggingface_hub

import yaml
MODEL_NAME="excelpdf"
# Defined in the secrets tab in Google Colab
api = HfApi(token=userdata.get(token))

# Upload merge folder
api.create_repo(
    repo_id=f"{username}/{MODEL_NAME}",
    repo_type="model",
    exist_ok=True,
)
api.upload_folder(
    repo_id=f"{username}/{MODEL_NAME}",
    folder_path="merge",
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
# ...
